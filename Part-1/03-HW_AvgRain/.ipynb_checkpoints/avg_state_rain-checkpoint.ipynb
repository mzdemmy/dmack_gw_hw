# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv

rain_data = pd.read_csv("Resources/avg_rain_state.csv")
rain_data.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
# Set x axis and tick locations

x_axis = np.arange(len(rain_data))
tick_locations = [value+0.4 for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space

plt.figure(figsize=(20,3))
plt.bar(x_axis, rain_data["Inches"], color='r', alpha=0.5, align="edge")
plt.xticks(tick_locations, rain_data["State"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="2000">
# ([<matplotlib.axis.XTick at 0x10942c630>,
#   <matplotlib.axis.XTick at 0x109442a90>,
#   <matplotlib.axis.XTick at 0x1094131d0>,
#   <matplotlib.axis.XTick at 0x11bdc8518>,
#   <matplotlib.axis.XTick at 0x11bdc89b0>,
#   <matplotlib.axis.XTick at 0x11bdc8e80>,
#   <matplotlib.axis.XTick at 0x11bdd1160>,
#   <matplotlib.axis.XTick at 0x11bdd15c0>,
#   <matplotlib.axis.XTick at 0x11bdd1a90>,
#   <matplotlib.axis.XTick at 0x11bdd1f60>,
#   <matplotlib.axis.XTick at 0x11bdd8470>,
#   <matplotlib.axis.XTick at 0x11bdd8940>,
#   <matplotlib.axis.XTick at 0x11bdd8e10>,
#   <matplotlib.axis.XTick at 0x11bde0320>,
#   <matplotlib.axis.XTick at 0x11bde07f0>,
#   <matplotlib.axis.XTick at 0x11bdd8898>,
#   <matplotlib.axis.XTick at 0x11bdd1b38>,
#   <matplotlib.axis.XTick at 0x11bde0b70>,
#   <matplotlib.axis.XTick at 0x11bde0080>,
#   <matplotlib.axis.XTick at 0x11bde7470>,
#   <matplotlib.axis.XTick at 0x11bde7940>,
#   <matplotlib.axis.XTick at 0x11bde7e10>,
#   <matplotlib.axis.XTick at 0x11bdef320>,
#   <matplotlib.axis.XTick at 0x11bdef7f0>,
#   <matplotlib.axis.XTick at 0x11bdefcc0>,
#   <matplotlib.axis.XTick at 0x11bdef3c8>,
#   <matplotlib.axis.XTick at 0x11bde7908>,
#   <matplotlib.axis.XTick at 0x11bdd1710>,
#   <matplotlib.axis.XTick at 0x11bdf9710>,
#   <matplotlib.axis.XTick at 0x11bdf9c88>,
#   <matplotlib.axis.XTick at 0x11bdff240>,
#   <matplotlib.axis.XTick at 0x11bdff7b8>,
#   <matplotlib.axis.XTick at 0x11bdffd30>,
#   <matplotlib.axis.XTick at 0x11be062e8>,
#   <matplotlib.axis.XTick at 0x11bdff630>,
#   <matplotlib.axis.XTick at 0x11bdf9668>,
#   <matplotlib.axis.XTick at 0x11be06b00>,
#   <matplotlib.axis.XTick at 0x11be06e48>,
#   <matplotlib.axis.XTick at 0x11be0d400>,
#   <matplotlib.axis.XTick at 0x11be0d978>,
#   <matplotlib.axis.XTick at 0x11be0def0>,
#   <matplotlib.axis.XTick at 0x11be154a8>,
#   <matplotlib.axis.XTick at 0x11be15a20>,
#   <matplotlib.axis.XTick at 0x11be15e80>,
#   <matplotlib.axis.XTick at 0x11be159e8>,
#   <matplotlib.axis.XTick at 0x11be06da0>,
#   <matplotlib.axis.XTick at 0x11bdf91d0>,
#   <matplotlib.axis.XTick at 0x11be1c4a8>,
#   <matplotlib.axis.XTick at 0x11be1ca20>,
#   <matplotlib.axis.XTick at 0x11be1ce80>],
#  <a list of 50 Text xticklabel objects>)

# %%
# Set x and y limits

plt.xlim(-0.25, len(x_axis))
plt.ylim(0, max(rain_data["Inches"])+10)
# Out:
# (0, 73.7)

# %%
# Set a Title and labels

plt.title("Average Rain per State")
plt.xlabel("State")
plt.ylabel("Average Amount of Rainfall in Inches")
# Out:
# Text(433.94444444444446, 0.5, 'Average Amount of Rainfall in Inches')

# %%
# Save our graph and show the grap

plt.tight_layout()
plt.savefig("Images/avg_state_rain2.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-a96c0d4bb064> in <module>
#       2
#       3 plt.tight_layout()
# ----> 4 plt.savefig("Images/avg_state_rain.png2")
#       5 plt.show()
#
# /Applications/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     714 def savefig(*args, **kwargs):
#     715     fig = gcf()
# --> 716     res = fig.savefig(*args, **kwargs)
#     717     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     718     return res
#
# /Applications/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2178             self.patch.set_visible(frameon)
#    2179
# -> 2180         self.canvas.print_figure(fname, **kwargs)
#    2181
#    2182         if frameon:
#
# /Applications/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2012
#    2013         # get canvas object and print method for format
# -> 2014         canvas = self._get_output_canvas(format)
#    2015         print_method = getattr(canvas, 'print_%s' % format)
#    2016
#
# /Applications/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in _get_output_canvas(self, fmt)
#    1954         raise ValueError(
#    1955             "Format {!r} is not supported (supported formats: {})"
# -> 1956             .format(fmt, ", ".join(sorted(self.get_supported_filetypes()))))
#    1957
#    1958     def print_figure(self, filename, dpi=None, facecolor=None, edgecolor=None,
#
# ValueError: Format 'png2' is not supported (supported formats: eps, jpeg, jpg, pdf, pgf, png, ps, raw, rgba, svg, svgz, tif, tiff)
